# %%
# !pip install -q datasets huggingface_hub pandas tqdm

# %% [markdown]
# # IndicVoices Dataset Exploration
#
# Internship Project
#
# Objective:
# - Read IndicVoices dataset
# - Filter required languages
# - Ensure speaker independence
# - Create train/validation/test CSV files

# %%
import random
from collections import defaultdict

import pandas as pd
from tqdm import tqdm

from datasets import load_dataset
from huggingface_hub import notebook_login

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %%
LANGUAGE = "hindi"

TRAIN_SAMPLES = 5000
VALID_SAMPLES = 1000
TEST_SAMPLES = 1000

SAMPLES_PER_SPEAKER = 10

TOTAL_SAMPLES = (
    TRAIN_SAMPLES +
    VALID_SAMPLES +
    TEST_SAMPLES
)

TOTAL_SPEAKERS = TOTAL_SAMPLES // SAMPLES_PER_SPEAKER

print("Language:", LANGUAGE)
print("Total speakers required:", TOTAL_SPEAKERS)
# Out:
# Language: hindi
# Total speakers required: 700

# %%
dataset = load_dataset(
    "ai4bharat/IndicVoices",
    LANGUAGE,
    split="train",
    streaming=True
)

print(dataset)
# Out:
# Resolving data files:   0%|          | 0/112 [00:00<?, ?it/s]
# Resolving data files:   0%|          | 0/82 [00:00<?, ?it/s]
# IterableDataset({
#     features: ['audio_filepath', 'text', 'duration', 'lang', 'samples', 'verbatim', 'normalized', 'speaker_id', 'scenario', 'task_name', 'gender', 'age_group', 'job_type', 'qualification', 'area', 'district', 'state', 'occupation', 'verification_report', 'unsanitized_verbatim', 'unsanitized_normalized'],
#     num_shards: 82
# })

# %%
sample = next(iter(dataset))

print("Keys:")
print(sample.keys())

print("\nSpeaker ID:", sample["speaker_id"])
print("Language  :", sample["lang"])
print("Gender    :", sample["gender"])
print("Age Group :", sample["age_group"])
print("State     :", sample["state"])
print("District  :", sample["district"])

print("\nText:")
print(sample["text"])

print("\nAudio type:")
print(type(sample["audio_filepath"]))

print("\nAudio object:")
print(sample["audio_filepath"])

# %%
sample = next(iter(dataset))

audio = sample["audio_filepath"]

print(type(audio))
print(audio.keys())

print("\nPath:")
print(audio["path"])

print("\nBytes present?")
print(audio["bytes"] is not None)

# %%
from datasets import load_dataset

dataset = load_dataset(
    "ai4bharat/IndicVoices",
    "hindi",
    split="train",
    streaming=True
)

# IMPORTANT: disable audio decoding
dataset = dataset.decode(False)

print(dataset)

# %%
from datasets import get_dataset_config_names

configs = get_dataset_config_names("ai4bharat/IndicVoices")

print(configs)

# %%
from huggingface_hub import HfApi

api = HfApi()

files = api.list_repo_files(
    repo_id="ai4bharat/IndicVoices",
    repo_type="dataset"
)

print("Total files:", len(files))

for f in files[:100]:
    print(f)

# %%
# Search for Hindi parquet files

for f in files:
    if f.startswith("hindi/"):
        print(f)

        # print only first 15
        if "00014" in f:
            break

# %%
from datasets import load_dataset

# Read ONLY ONE parquet shard
parquet = load_dataset(
    "parquet",
    data_files="hf://datasets/ai4bharat/IndicVoices/hindi/train-00000-of-00082.parquet"
)

print(parquet)

# %%
from datasets import load_dataset
from collections import Counter
import gc

speaker_counts = Counter()

for shard in range(82):

    print(f"\nProcessing shard {shard+1}/82")

    filename = f"hf://datasets/ai4bharat/IndicVoices/hindi/train-{shard:05d}-of-00082.parquet"

    parquet = load_dataset(
        "parquet",
        data_files=filename
    )

    for speaker in parquet["train"]["speaker_id"]:
        speaker_counts[speaker] += 1

    del parquet
    gc.collect()   # Force memory cleanup after every shard

print("Done!")
print("Unique speakers:", len(speaker_counts))
# Out:
# Processing shard 1/82
# hindi/train-00000-of-00082.parquet:   0%|          | 0.00/500M [00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Processing shard
[00:00<?, ?B/s]
# Generating train split: 0 examples [00:00, ? examples/s]
# Done!
# Unique speakers: 2354

# %%
eligible_speakers = {
    sp: cnt
    for sp, cnt in speaker_counts.items()
    if cnt >= 10
}

print("Speakers with >=10 recordings:", len(eligible_speakers))
# Out:
# Speakers with >=10 recordings: 2350

# %%
selected_speakers = list(eligible_speakers.keys())[:700]

print(len(selected_speakers))
# Out:
# 700

# %%
import json

with open("/kaggle/working/selected_speakers.json", "w") as f:
    json.dump(selected_speakers, f)

print("Saved!")
# Out:
# Saved!

# %%
with open("/kaggle/working/eligible_speakers.json", "w") as f:
    json.dump(eligible_speakers, f)

print("Eligible speakers saved!")
# Out:
# Eligible speakers saved!

# %%
with open("/kaggle/working/speaker_counts.json", "w") as f:
    json.dump(speaker_counts, f)

print("Speaker counts saved!")
# Out:
# Speaker counts saved!

# %%
selected_speakers = [
    sp for sp, cnt in sorted(
        eligible_speakers.items(),
        key=lambda x: x[1],
        reverse=True
    )[:700]
]

print("Selected speakers:", len(selected_speakers))
# Out:
# Selected speakers: 700

# %%
import random

random.seed(42)

random.shuffle(selected_speakers)

train_speakers = set(selected_speakers[:500])
valid_speakers = set(selected_speakers[500:600])
test_speakers = set(selected_speakers[600:700])

print("Train speakers :", len(train_speakers))
print("Validation speakers :", len(valid_speakers))
print("Test speakers :", len(test_speakers))
# Out:
# Train speakers : 500
# Validation speakers : 100
# Test speakers : 100

# %%
import json

with open("/kaggle/working/train_speakers.json", "w") as f:
    json.dump(list(train_speakers), f)

with open("/kaggle/working/valid_speakers.json", "w") as f:
    json.dump(list(valid_speakers), f)

with open("/kaggle/working/test_speakers.json", "w") as f:
    json.dump(list(test_speakers), f)

print("Speaker splits saved successfully!")
# Out:
# Speaker splits saved successfully!

# %%
with open("/kaggle/working/selected_speakers.json", "w") as f:
    json.dump(selected_speakers, f)

print("Selected speakers saved!")
# Out:
# Selected speakers saved!

# %%
from datasets import load_dataset
from collections import defaultdict
import os
import csv
import soundfile as sf
from io import BytesIO
import gc

# %%
os.makedirs("/kaggle/working/train/audio", exist_ok=True)
os.makedirs("/kaggle/working/valid/audio", exist_ok=True)
os.makedirs("/kaggle/working/test/audio", exist_ok=True)

# %%
speaker_recordings = defaultdict(int)

train_rows = []
valid_rows = []
test_rows = []

TARGET = 10

# %%
sample = next(iter(dataset))

audio = sample["audio_filepath"]

print(type(audio))
print(audio)
# Out:
# <class 'datasets.features._torchcodec.AudioDecoder'>
# <datasets.features._torchcodec.AudioDecoder object at 0x7f2a4a8cd550>

# %%
from datasets import load_dataset
from collections import defaultdict
import pandas as pd
import gc

speaker_count = defaultdict(int)

rows = []

# %%
sample = ds[0]

audio = sample["audio_filepath"]

print(type(audio))

print(dir(audio)[:50])
# Out:
# <class 'datasets.features._torchcodec.AudioDecoder'>
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getitem__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_decoder', '_desired_sample_rate', '_hf_encoded', 'get_all_samples', 'get_samples_played_in_range', 'metadata', 'stream_index']

# %%
print(hasattr(audio, "get_all_samples"))
print(hasattr(audio, "array"))
print(hasattr(audio, "sampling_rate"))
# Out:
# True
# False
# False

# %%
sample = ds[0]

decoded = sample["audio_filepath"].get_all_samples()

print(type(decoded))
print(dir(decoded))

print(decoded.sample_rate)
print(decoded.data.shape)
# Out:
# <class 'torchcodec._frame.AudioSamples'>
# ['__abstractmethods__', '__annotations__', '__class__', '__class_getitem__', '__dataclass_fields__', '__dataclass_params__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__match_args__', '__module__', '__ne__', '__new__', '__post_init__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__slots__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', 'data', 'duration_seconds', 'pts_seconds', 'sample_rate']
# 16000
# torch.Size([1, 411104])

# %%
# !pip install soundfile pandas -q

# %%
for shard in range(82):

    print(f"\nProcessing shard {shard+1}/82")

    filename = f"hf://datasets/ai4bharat/IndicVoices/hindi/train-{shard:05d}-of-00082.parquet"

    ds = load_dataset(
        "parquet",
        data_files=filename,
        split="train"
    )

    for sample in ds:

        speaker = sample["speaker_id"]

        if speaker not in selected_speakers:
            continue

        if speaker_counter[speaker] >= TARGET:
            continue

        decoded = sample["audio_filepath"].get_all_samples()

        waveform = decoded.data.squeeze().numpy()
        sr = decoded.sample_rate

        if speaker in train_speakers:
            split = "train"
        elif speaker in valid_speakers:
            split = "valid"
        else:
            split = "test"

        filename = f"{speaker}_{speaker_counter[speaker]}.wav"

        save_path = os.path.join(
            base_dir,
            split,
            filename
        )

        sf.write(save_path, waveform, sr)

        row = {
            "speaker_id": speaker,
            "audio": filename,
            "text": sample["text"],
            "gender": sample["gender"],
            "state": sample["state"],
            "district": sample["district"]
        }

        if split == "train":
            train_rows.append(row)
        elif split == "valid":
            valid_rows.append(row)
        else:
            test_rows.append(row)

        speaker_counter[speaker] += 1

    del ds
    gc.collect()

    print("Collected:", sum(speaker_counter.values()))

    if sum(speaker_counter.values()) >= 7000:
        print("Done collecting!")
        break
# Out:
# Processing shard 1/82
# Collected: 1485
#
# Processing shard 2/82
# Collected: 2598
#
# Processing shard 3/82
# Collected: 3319
#
# Processing shard 4/82
# Collected: 3893
#
# Processing shard 5/82
# Collected: 4316
#
# Processing shard 6/82
# Collected: 4654
#
# Processing shard 7/82
# Collected: 4929
#
# Processing shard 8/82
# Collected: 5082
#
# Processing shard 9/82
# Collected: 5185
#
# Processing shard 10/82
# Collected: 5284
#
# Processing shard 11/82
# Collected: 5364
#
# Processing shard 12/82
# Collected: 5496
#
# Processing shard 13/82
# Collected: 5586
#
# Processing shard 14/82
# Collected: 5610
#
# Processing shard 15/82
# Collected: 5657
#
# Processing shard 16/82
# Collected: 5696
#
# Processing shard 17/82
# Collected: 5721
#
# Processing shard 18/82
# Collected: 5741
#
# Processing shard 19/82
# Collected: 5760
#
# Processing shard 20/82
# Collected: 5785
#
# Processing shard 21/82
# Collected: 5801
#
# Processing shard 22/82
# Collected: 5812
#
# Processing shard 23/82
# Collected: 5844
#
# Processing shard 24/82
# Collected: 5860
#
# Processing shard 25/82
# Collected: 5864
#
# Processing shard 26/82
# Collected: 6212
#
# Processing shard 27/82
# Collected: 6417
#
# Processing shard 28/82
# Collected: 6548
#
# Processing shard 29/82
# Collected: 6628
#
# Processing shard 30/82
# Collected: 6712
#
# Processing shard 31/82
# Collected: 6737
#
# Processing shard 32/82
# Collected: 6772
#
# Processing shard 33/82
# Collected: 6790
#
# Processing shard 34/82
# Collected: 6800
#
# Processing shard 35/82
# Collected: 6806
#
# Processing shard 36/82
# Collected: 6809
#
# Processing shard 37/82
# Collected: 6809
#
# Processing shard 38/82
# Collected: 6809
#
# Processing shard 39/82
# Collected: 6809
#
# Processing shard 40/82
# Collected: 6809
#
# Processing shard 41/82
# Collected: 6809
#
# Processing shard 42/82
# Collected: 6810
#
# Processing shard 43/82
# Collected: 6810
#
# Processing shard 44/82
# Collected: 6811
#
# Processing shard 45/82
# Collected: 6811
#
# Processing shard 46/82
# Collected: 6812
#
# Processing shard 47/82
# Collected: 6812
#
# Processing shard 48/82
# Collected: 6812
#
# Processing shard 49/82
# Collected: 6812
#
# Processing shard 50/82
# Collected: 6812
#
# Processing shard 51/82
# Collected: 6818
#
# Processing shard 52/82
# Collected: 6820
#
# Processing shard 53/82
# Collected: 6820
#
# Processing shard 54/82
# Collected: 6820
#
# Processing shard 55/82
# Collected: 6820
#
# Processing shard 56/82
# Collected: 6820
#
# Processing shard 57/82
# Collected: 6820
#
# Processing shard 58/82
# Collected: 6827
#
# Processing shard 59/82
# Collected: 6827
#
# Processing shard 60/82
# Collected: 6827
#
# Processing shard 61/82
# Collected: 6827
#
# Processing shard 62/82
# Collected: 6853
#
# Processing shard 63/82
# Collected: 6873
#
# Processing shard 64/82
# Collected: 6878
#
# Processing shard 65/82
# Collected: 6884
#
# Processing shard 66/82
# Collected: 6886
#
# Processing shard 67/82
# Collected: 6886
#
# Processing shard 68/82
# Collected: 6931
#
# Processing shard 69/82
# Collected: 6931
#
# Processing shard 70/82
# Collected: 6931
#
# Processing shard 71/82
# Collected: 6931
#
# Processing shard 72/82
# Collected: 6931
#
# Processing shard 73/82
# Collected: 6931
#
# Processing shard 74/82
# Collected: 6978
#
# Processing shard 75/82
# Collected: 6995
#
# Processing shard 76/82
# Collected: 7000
# Done collecting!

# %%
print(len(train_speakers))
print(len(valid_speakers))
print(len(test_speakers))

print(os.listdir("/kaggle/working/IndicVoices700"))
# Out:
# 500
# 100
# 100
# ['train', 'test', 'valid']

# %%
print(len(train_rows))
print(len(valid_rows))
print(len(test_rows))
# Out:
# 5000
# 1000
# 1000

# %%
import pandas as pd

pd.DataFrame(train_rows).to_csv(
    f"{base_dir}/train_metadata.csv",
    index=False
)

pd.DataFrame(valid_rows).to_csv(
    f"{base_dir}/valid_metadata.csv",
    index=False
)

pd.DataFrame(test_rows).to_csv(
    f"{base_dir}/test_metadata.csv",
    index=False
)

print("Metadata saved!")
# Out:
# Metadata saved!

# %%
import os

print("Train:", len(os.listdir(f"{base_dir}/train")))
print("Valid:", len(os.listdir(f"{base_dir}/valid")))
print("Test :", len(os.listdir(f"{base_dir}/test")))
# Out:
# Train: 5000
# Valid: 1000
# Test : 1000

# %%
import shutil

shutil.make_archive(
    "/kaggle/working/IndicVoices700",
    "zip",
    base_dir
)

print("Zip created!")
# Out:
# Zip created!

# %%
import shutil

shutil.make_archive("/kaggle/working/train", "zip",
                    "/kaggle/working/IndicVoices700/train")

shutil.make_archive("/kaggle/working/valid", "zip",
                    "/kaggle/working/IndicVoices700/valid")

shutil.make_archive("/kaggle/working/test", "zip",
                    "/kaggle/working/IndicVoices700/test")

print("Done!")
# Out:
# Done!
